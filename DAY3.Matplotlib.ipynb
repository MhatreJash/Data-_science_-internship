# %%
import matplotlib.pyplot as plt
#create data for plotting

x_values=[0,1,2,3,4,5]
y_values=[0,1,4,9,16,25]

plt.plot(x_values,y_values)

#display the graph
plt.show()

# %%
import matplotlib.pyplot as plt
plt.plot([1,2,3,4])
plt.ylabel('Some number')
plt.show()

# %%
import matplotlib.pyplot as plt

values=[5,6,3,7,2]
names=["A","B","C","D", "E"]

plt.bar(names,values,color="green")
plt.show()

# %%
import matplotlib.pyplot as plt

ages=[2,5,70,40,30,45,50,45,43,40,44,60,7,13,57,18,90,77,32,21,40]

range=(0,100)
bins=10

plt.hist(ages,bins,range, color='green',histtype='bar', edgecolor='black', alpha=0.5);

plt.xlable('age');
plt.ylable("no of people");
plt.title("my histrogram");
plt.show()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-12-06728e8cb38f> in <cell line: 10>()
#       8 plt.hist(ages,bins,range, color='green',histtype='bar', edgecolor='black', alpha=0.5);
#       9
# ---> 10 plt.xlable('age');
#      11 plt.ylable("no of people");
#      12 plt.title("my histrogram");
#
# AttributeError: module 'matplotlib.pyplot' has no attribute 'xlable'

# %%
import matplotlib.pyplot as plt

x_values=[0,1,2,3,4,5]
y_values=[0,1,4,9,16,25]

plt.scatter(x_values,y_values, label="stars",marker="*", s=30, color="blue")
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
import matplotlib.pyplot as plt


activites=['eat','sleep','work','play']

slices=[3,7,8,6]

colors=['r','y','g','b']

plt.pie(slice, labels=activites, colors=colors, startangle=90, shadow=True, explode=(0,0,0.1,0), radius=1.2, autopct='%1.1f%%')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-17-73ffaeb859d9> in <cell line: 10>()
#       8 colors=['r','y','g','b']
#       9
# ---> 10 plt.pie(slice, labels=activites,colors=colors, startangle=90,shadow=true, explode=(0,0,0.1,0), radius=1.2, autopct='%1.1f%%')
#
# NameError: name 'true' is not defined

# %%
import matplotlib.pyplot as plt

activities = ['eat', 'sleep', 'work', 'play']
slices = [3, 7, 8, 6]
colors = ['r', 'y', 'g', 'b']

plt.pie(slices, labels=activities, colors=colors, startangle=90, shadow=True, explode=(0, 0, 0.1, 0), radius=1.2, autopct='%1.1f%%')
plt.axis('equal')  # Equal aspect ratio ensures that pie is drawn as a circle.

plt.show()

# %%
import matplotlib.pyplot as plt
import pandas as ps
df=pd.read_csv('/content/demo.csv')
x=df['model']
y=df['price']
plt.bar(x,y)
plt.show()
